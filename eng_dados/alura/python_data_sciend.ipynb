# %%
# !pip install matplotlib numpy

# %%
import matplotlib.pyplot as plt
from math import *
from random import choices, randrange, randint

# %%
estudantes = ['Pedro', 'Yago', 'Patricia']
notas = [6, 8.5, 10]

# %%
plt.bar(x=estudantes, height=notas)
# Out:
# <BarContainer object of 3 artists>

# %%
estudante = choices(estudantes)
estudante
# Out:
# ['Yago']

# %%
import numpy as np

# %%
lista = [6,12,54,23,43,1,90,87,105,77]

number = np.random.choice(lista)
number
# Out:
# np.int64(77)

# %%
pos = randrange(100)
pos
# Out:
# 91

# %%
numbers = input("Digite 2 numeros inteiros separados por espaço: ")
numbers = numbers.split()
pow(int(numbers[0]), int(numbers[1]))
# Out:
# 8.0

# %%
list_numbers = int(input("Digite o numero de participantes: "))

winner = randint(1, list_numbers)
winner
# Out:
# 1

# %%
nome = input("Digite o seu nome: ")

token = 1

while token % 2 != 0:

    token = randint(1000, 9998)


f"Olá, {nome}, o seu token de acesso é {token}! Seja bem-vindo(a)!"
# Out:
# 'Olá, Pedro, o seu token de acesso é 9546! Seja bem-vindo(a)!'

# %%
frutas = ["maçã", "banana", "uva", "pêra", 
          "manga", "coco", "melancia", "mamão",
          "laranja", "abacaxi", "kiwi", "ameixa"]

primeira_fruta = np.random.choice(frutas)
frutas.remove(primeira_fruta)
segunda_fruta = np.random.choice(frutas)
frutas.remove(segunda_fruta)
terceira_fruta = np.random.choice(frutas)

f"Sua salada de frutas é composta por {primeira_fruta}, {segunda_fruta} e {terceira_fruta}"
# Out:
# 'Sua salada de frutas é composta por coco, pêra e uva'

# %%
numeros = [2, 8, 15, 23, 91, 112, 256]

raiz = [x for x in numeros if sqrt(x).is_integer()]
raiz
# Out:
# [256]

# %%
raio = float(input('Digite o raio em m² que deseja: '))

valor = (raio * pow(pi, 2)) * 25

valor
# Out:
# 2960.8813203268073
