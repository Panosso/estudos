# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import randint, sample

#Comando para fazer os graficos aparecerem na pagina atual, conhecido como comando mágico
# %matplotlib inline

# %%
x1 = [x for x in range(4)]
y1 = [x for x in range(4, 8)]
plt.plot(x1, y1)

plt.show()

# %%
x = [11,12,13]
y = [4,5,6]
plt.xlabel("Label X")
plt.ylabel("Label Y")
plt.title("Titulo Graf")
plt.plot(x, y, label = "Teste label")
plt.legend()

# %%
plt.bar(x,y, label='Lista1', color='Blue')
plt.bar(x1,y1, label='Lista1', color='Red')
plt.legend()
plt.show()

# %%
idades = [ randint(0, x) for x in range(100)]
ids = [x for x in range(len(idades))]

# %%
plt.bar(ids, idades)
# Out:
# <BarContainer object of 100 artists>

# %%
#representação de um histograma
plt.hist(idades, ids, histtype='stepfilled', rwidth=0.8)
plt.show()

# %%
#Grafico de dispoersão
x = [x for x in range(10)]
y = [x for x in range(10, 20)]

# %%
plt.scatter(x, y, label = 'Pontos', color = 'black', marker='*')

# %%
dias = [x for x in range(10)]
dormir = [x for x in range(10,20)]
comer = [x for x in range(20, 30)]
trabalhar = [x for x in range(30, 40)]
passear = [x for x in range(40, 50)]

# %%
plt.stackplot(dias, dormir, comer, trabalhar, passear, colors=['m', 'c', 'r', 'k', 'b'])
plt.show()

# %%
fatias = [7, 2, 2, 13]
atividades = ['dormi', 'comer', 'passear', 'trabalhar']
cores = ['olive', 'lime', 'violet', 'royalblue']

# %%
#Grafico de pizza
plt.pie(fatias, labels= atividades, colors=cores, startangle=90, shadow=True, explode=(0, 0.2,0,0))
plt.show()

# %%
#usando o pylab: Biblioteca que junta as funções do NumPy e do matplotlib
import pylab as pl
from math import exp

# %%
#dados
x = pl.linspace(0,5,10)
y = x ** 2

#cria a figura
fig = plt.figure()

axes = fig.add_axes([0, 0, 0.8, 0.8])

axes.plot(x, y, 'r')

# %%
#cria a figura
fig = plt.figure()

axes = fig.add_axes([0, 0, 0.8, 0.8])

axes.plot(x, y, 'r')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('Title1')

axes2.plot(x, y, 'g')
axes2.set_xlabel('x')
axes2.set_ylabel('y')
axes2.set_title('Title2')

fig.show()
# Out:
# C:\Users\Pedro Machado\AppData\Local\Temp\ipykernel_10708\440171667.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'r')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('Title')

fig.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(x, x**2, x)
axes[0].set_title('Escala Padrao')

axes[1].plot(x, x**2, x)
axes[1].set_yscale("log")
axes[1].set_title('Escala log y')
# Out:
# Text(0.5, 1.0, 'Escala log y')

# %%
fig, axes = plt.subplots(1, 4, figsize = (12,3))

# Grid padrão
axes[0].plot(x, x**2, x, x**3, lw = 2)
axes[0].grid(True)

# Grid customizado
axes[1].plot(x, x**2, x, x**3, lw = 2)

# %%
# Subplots
fig, axes = plt.subplots(1, 4, figsize = (12,3))
n = np.array([x for x in range(50)])

# Plot 1
axes[0].scatter(x, x + 0.25 * randint(0, len(x)), color = "black")
axes[0].set_title("scatter")

# Plot 2
axes[1].step(n, n ** 2, lw = 2, color = "blue")
axes[1].set_title("step")

# Plot 3
axes[2].bar(n, n ** 2, align = "center", width = 0.5, alpha = 0.5, color = "magenta")
axes[2].set_title("bar")

# Plot 4
axes[3].fill_between(x, x ** 2, x ** 3, alpha = 0.5, color = "green");
axes[3].set_title("fill_between");

# %%
# Histogramas

# Dados
n = np.random.randn(100000)

# Cria os subplots
fig, axes = plt.subplots(1, 2, figsize = (12,4))

# Plot 1
axes[0].hist(n)
axes[0].set_title("Histograma Padrão")
axes[0].set_xlim((min(n), max(n)))

# Plot 2
axes[1].hist(n, cumulative = True, bins = 50)
axes[1].set_title("Histograma Cumulativo")
axes[1].set_xlim((min(n), max(n)));

# %%
#Graficos 3D
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def color_map(phi_m, phi_p):
    return (alpha -2 * np.cos(phi_p)*np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p))

# Mais dados
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = color_map(X, Y).T

# %%
# Cria a figura
fig = plt.figure(figsize = (14,6))

# Adiciona o subplot 1 com projeção 3d
ax = fig.add_subplot(1, 2, 1, projection = '3d')
p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# Adiciona o subplot 2 com projeção 3d
ax = fig.add_subplot(1, 2, 2, projection = '3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='Accent', linewidth=0, antialiased=False)

# Cria a barra de cores como legenda
cb = fig.colorbar(p, shrink=0.5)

# %%
#Exemplo com seaborn
import seaborn as sea
import warnings
warnings.filterwarnings("ignore")

# %%
# Carregando um dos datasets que vem com o Seaborn
dados = sea.load_dataset("tips")
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# O método joinplot cria plot de 2 variáveis com gráficos bivariados e univariados
sea.jointplot(data = dados, x = "total_bill", y = "tip", kind = 'reg')

# %%
# O método lmplot() cria plot com dados e modelos de regressão
sea.lmplot(data = dados, x = "total_bill", y = "tip", col = "smoker")

# %%
#Df com pandas
df = pd.DataFrame()
df['idade'] = sample(range(20, 100), 30)
df['peso'] = sample(range(55, 150), 30)

# %%
# lmplot
sea.lmplot(data = df, x = "idade", y = "peso", fit_reg = True)

# %%
# kdeplot
sea.kdeplot(df.idade)
# Out:
# <Axes: xlabel='idade', ylabel='Density'>

# %%
# kdeplot
sea.kdeplot(df.peso)
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
# distplot
sea.distplot(df.peso)
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
# Histograma
plt.hist(df.idade, alpha = .3)
sea.rugplot(df.idade)
# Out:
# <Axes: xlabel='idade'>

# %%
# Box Plot
sea.boxplot(df.peso, color = 'y')
# Out:
# <Axes: ylabel='peso'>

# %%
# Violin Plot
sea.violinplot(df.idade, color = 'g')
# Out:
# <Axes: ylabel='idade'>

# %%
# Clustermap
sea.clustermap(df)

# %%
# Valores randômicos
np.random.seed(42)
n = 1000
pct_smokers = 0.2

# Variáveis
flag_fumante = np.random.rand(n) < pct_smokers
idade = np.random.normal(40, 10, n)
altura = np.random.normal(170, 10, n)
peso = np.random.normal(70, 10, n)

# Dataframe
dados = pd.DataFrame({'altura': altura, 'peso': peso, 'flag_fumante': flag_fumante})

# Cria os dados para a variável flag_fumante
dados['flag_fumante'] = dados['flag_fumante'].map({True: 'Fumante', False: 'Não Fumante'})

# %%
# Style
sea.set(style = "ticks")

# lmplot
sea.lmplot(x = 'altura', 
           y = 'peso', 
           data = dados, 
           hue = 'flag_fumante', 
           palette = ['tab:blue', 'tab:orange'], 
           height = 7)

# Labels e título
plt.xlabel('Altura (cm)')
plt.ylabel('Peso (kg)')
plt.title('Relação Entre Altura e Peso de Fumantes e Não Fumantes')

# Remove as bordas
sea.despine()

# Show
plt.show()
